# %%
import pandas as pd
import numpy as np

# %%
data_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data'
df_data = pd.read_csv(data_url, sep='\s+', header=None) 
# 
df_data.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
df_data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
# df_data.values
df_data.values[0]
# Out:
# array([6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
#        6.520e+01, 4.090e+00, 1.000e+00, 2.960e+02, 1.530e+01, 3.969e+02,
#        4.980e+00, 2.400e+01])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_data['weight_0'] = 1 
df_data.head() 
# weight_0 이라는 이름의 열이 생성되었으며 각 값은 모두 1로 지정됨을 확
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV  weight_0
# 0     15.3  396.90   4.98  24.0         1
# 1     17.8  396.90   9.14  21.6         1
# 2     17.8  392.83   4.03  34.7         1
# 3     18.7  394.63   2.94  33.4         1
# 4     18.7  396.90   5.33  36.2         1

# %%
df_data = df_data.drop("MEDV", axis=1) #Y값 (MEDV) 제거, 두번 실행하면 오류 발생 --> why? 한번 이미 drop 된 것에 한하여 두번 drop 발생 x

# %%
df_data.values
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 3.9690e+02, 4.9800e+00,
#         1.0000e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 3.9690e+02, 9.1400e+00,
#         1.0000e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 3.9283e+02, 4.0300e+00,
#         1.0000e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 3.9690e+02, 5.6400e+00,
#         1.0000e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 3.9345e+02, 6.4800e+00,
#         1.0000e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 3.9690e+02, 7.8800e+00,
#         1.0000e+00]])

# %% [markdown]
# df_data.as_matrix() 는 구버전의 pandas에서 이용, 현재는 지원 x <br>
# as_matrix() 대신에 values 속성을 사용할 수 있다.

# %%
df_data.shape
# Out:
# (506, 14)

# %% [markdown]
# (506행 14열) : 이게 X 값임 <br>
# 이거를 통해 예측하고자 하는 종속변수 Y값은 506 by 1 matrix 형태여야 함  <br>
# 당연하게도 weight 는 14 by 1 형태가 되어야 함

# %%
df_matrix = df_data.values #matrix data로 변환하기 
weight_vector = np.random.random_sample((14, 1))   # column 벡터 형태의 14 by 1

# %%
weight_vector
# Out:
# array([[0.94458837],
#        [0.79939861],
#        [0.20105026],
#        [0.71288903],
#        [0.5813692 ],
#        [0.49451755],
#        [0.58233923],
#        [0.61393378],
#        [0.69562192],
#        [0.97370687],
#        [0.31606985],
#        [0.03403742],
#        [0.08949494],
#        [0.5744278 ]])

# %%
Y = df_matrix.dot(weight_vector)
# 예상했듯 506 by 1 
Y.shape
# Out:
# (506, 1)

# %% [markdown]
# ![image.png](attachment:image.png)
